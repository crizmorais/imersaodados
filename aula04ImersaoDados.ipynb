# %%
import pandas as pd
 
url_exper = "https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true"
 
dados = pd.read_csv(url_exper, compression = 'zip')
 
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ###AULA 01
# Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %% [markdown]
# Pouco menos de 8% são controle.

# %%
print(dados['tratamento'].value_counts(), '\n')
print(dados['tratamento'].value_counts(normalize = True))
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64
#
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Separar entre "com_droga" e "com_controle":

# %%
dados_controle = dados[dados['tratamento'] == 'com_controle']
dados_droga = dados[dados['tratamento'] == 'com_droga']

#verificando quantas ocorrências

print('Número de ocorrências: \n Controle: {} \n Droga: {}'.format(dados_controle.shape, dados_droga.shape))
# Out:
# Número de ocorrências:
#  Controle: (1866, 877)
#  Droga: (21948, 877)

# %% [markdown]
# Agora é possível investigar as duas variáveis separadamente.

# %%
print(dados_controle['tempo'].value_counts(), '- com_controle' '\n')
print(dados_controle['tempo'].value_counts(normalize = True), '- com_controle' '\n')
print(dados_droga['tempo'].value_counts(), '- com_droga' '\n')
print(dados_droga['tempo'].value_counts(normalize = True), '- com_droga')
# Out:
# 48    648
# 72    612
# 24    606
# Name: tempo, dtype: int64 - com_controle
#
# 48    0.347267
# 72    0.327974
# 24    0.324759
# Name: tempo, dtype: float64 - com_controle
#
# 48    7602
# 72    7180
# 24    7166
# Name: tempo, dtype: int64 - com_droga
#
# 48    0.346364
# 72    0.327137
# 24    0.326499
# Name: tempo, dtype: float64 - com_droga

# %%
print(dados_controle['dose'].value_counts(), '- com_controle' '\n')
print(dados_controle['dose'].value_counts(normalize = True), '- com_controle' '\n')
print(dados_droga['dose'].value_counts(), '- com_droga' '\n')
print(dados_droga['dose'].value_counts(normalize = True), '- com_droga')
# Out:
# D1    951
# D2    915
# Name: dose, dtype: int64 - com_controle
#
# D1    0.509646
# D2    0.490354
# Name: dose, dtype: float64 - com_controle
#
# D1    11196
# D2    10752
# Name: dose, dtype: int64 - com_droga
#
# D1    0.510115
# D2    0.489885
# Name: dose, dtype: float64 - com_droga

# %% [markdown]
# O tempo apresentou uma proporção parecida para ambos os casos. Dose também apresentou certa proporcionalidade.

# %%
print(dados_controle['droga'].value_counts(), '- com_controle' '\n')
print(dados_controle['droga'].value_counts(normalize = True), '- com_controle' '\n')
print(dados_droga['droga'].value_counts(), '- com_droga' '\n')
print(dados_droga['droga'].value_counts(normalize = True), '- com_droga')
# Out:
# cacb2b860    1866
# Name: droga, dtype: int64 - com_controle
#
# cacb2b860    1.0
# Name: droga, dtype: float64 - com_controle
#
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# 06787fefe      1
# 8bc88a3be      1
# d70cdde82      1
# 19b95658c      1
# 4a8eda087      1
# Name: droga, Length: 3288, dtype: int64 - com_droga
#
# 87d714366    0.032714
# 9f80f3f77    0.011208
# 8b87a7a83    0.009249
# 5628cb3ee    0.009204
# d08af5d4b    0.008930
#                ...
# 06787fefe    0.000046
# 8bc88a3be    0.000046
# d70cdde82    0.000046
# 19b95658c    0.000046
# 4a8eda087    0.000046
# Name: droga, Length: 3288, dtype: float64 - com_droga

# %% [markdown]
# Observa-se acima a quantidade de tipos diferentes de drogas aplicadas (n = 3288 para o grupo com_droga e n = 1 para o grupo com_controle). O desbalanceamento nos números absolutos entre os grupos com_droga e com_controle pode ser devido a esse grande número de drogas diferentes utilizadas, umas vez que não é necessário uma amostra de controle tão grande para comparações entre os grupos.

# %% [markdown]
# Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
#o método .head() mostra as 5 primeiras linhas e o método .tail() mostra as 5 últimas
dados.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b72a95fe268e> in <module>()
#       1 #o método .head() mostra as 5 primeiras linhas e o método .tail() mostra as 5 últimas
# ----> 2 dados.tail()
#
# NameError: name 'dados' is not defined

# %% [markdown]
# desafio 03: Proporção das classes tratamento.#

# %%
#podemos usar dentro do método .value_counts() o parâmetro 'normalize = True'. Por exemplo:

dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Desafio 04: Quantos tipos de drogas foram investigadas:

# %%
print(dados_controle['droga'].value_counts(), '- com_controle' '\n')
print(dados_droga['droga'].value_counts(), '- com_droga' '\n')
print('Se somarmos a droga utilizada no grupo controle, dá um total de 3289 drogas')
# Out:
# cacb2b860    1866
# Name: droga, dtype: int64 - com_controle
#
# 87d714366    718
# 9f80f3f77    246
# 8b87a7a83    203
# 5628cb3ee    202
# d08af5d4b    196
#             ...
# 06787fefe      1
# 8bc88a3be      1
# d70cdde82      1
# 19b95658c      1
# 4a8eda087      1
# Name: droga, Length: 3288, dtype: int64 - com_droga
#
# Se somarmos a droga utilizada no grupo controle, dá um total de 3289 drogas

# %% [markdown]
# Desafio 05: Método query do Pandas
# Esse método tem certo problema com o hífen, então antes vamos renomear as colunas que possuem esse caractere.
# Desafio 05 e 06: Renomear as colunas e aplicar o método query:

# %%
dados_novos = dados.rename(lambda x: x.replace('-', ''), axis=1)
dados_novos.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
#Utilizando o método query

dados_novos.query('g0 > 1')
# Out:
#                  id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0      id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 6      id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 16     id_002fb9c19  com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 39     id_0079d45d3  com_droga     24   D1  ... -2.7020 -2.2530 -4.8360 -0.6461
# 48     id_008b48693  com_droga     24   D1  ... -0.2725 -0.1511 -0.4635 -0.1365
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23749  id_ff4fcb445  com_droga     48   D1  ...  1.4160  0.2399 -0.4236  0.7803
# 23776  id_ff9d0a022  com_droga     24   D2  ... -7.5290 -6.3180 -5.7010 -3.5610
# 23791  id_ffd1fd119  com_droga     72   D2  ... -9.9660 -8.6420 -9.9660 -4.6050
# 23802  id_fff3976bd  com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5  com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
#
# ...

# %% [markdown]
# Desafio 07: Deixar os gráficos mais bonitões:

# %%
#importando as bibliotecas

import numpy as np
import matplotlib.pyplot as plt

# %%
#gráfico de barras

dados['tempo'].value_counts().plot.bar(color = "green")

fonte = {'family':'serif','color':'black','size': 24}

plt.title('Tempo', fontdict = fonte)
plt.xlabel('Horas')
plt.ylabel('Frequência')
# Out:
# Text(0, 0.5, 'Frequência')

# %%
#gráfico de pizza

dados['tempo'].value_counts().plot.pie(autopct= '%1.1f%%')

fonte = {'family':'serif','color':'black','size': 18}

plt.title('Tempo', fontdict = fonte)
# Out:
# Text(0.5, 1.0, 'Tempo')

# %% [markdown]
# Desafio 08: Resumo do aprendizado
#
# Bom, sobre o assunto do qual se trata a base de dados, eu não sabia nada, então qualquer ensinamentos sobre a área, por mais raso que seja, já aumenta em muito o meu conhecimento sobre.
#
# Eu já tinha utilizado a biblioteca do Pandas, mas apenas por curiosidade, e não me aprofundei nela; logo, assim como dito acima sobre farmacologia, foi interessante descobrir recursos novos da biblioteca, seja para filtragem de dados, ou para a apresentação deles de forma mais clara com os gráficos.
#
# A proposta agora é levar essas descobertas para a minha área, e ver como posso resolver os meus próprios problemas.

# %% [markdown]
# ###AULA 02

# %%
mapa = {'droga':'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %%
cod_compostos = dados['composto'].value_counts().index[:5]

# %%
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos').head()
# Out:
#               id    tratamento  tempo dose  ...    c-96    c-97    c-98   c-99
# 7   id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.026
# 16  id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.784
# 25  id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.005
# 38  id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.482
# 40  id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.918
#
# [5 rows x 877 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
plt.figure(figsize=(8, 6))

ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 Compostos')

plt.show()

# %%
plt.figure(figsize=(8,6))
ax = sns.countplot(x = 'composto', data = dados.query('composto in @cod_compostos'), order=dados.query('composto in @cod_compostos')['composto'].value_counts().index)
ax.set_title('Top 5 Compostos')

plt.show()

# %%
len(dados['g-0'].unique())
# Out:
# 14367

# %%
dados['g-0'].max()
# Out:
# 10.0

# %%
dados['g-0'].hist(bins = 100)

# %%
#testando histogramas com outras variáveis

g_76 = dados['g-76']

plt.figure(figsize=(12,10))
sns.histplot(g_76, bins=100, kde=True)
plt.show()
#dados['g-76'].hist(bins = 100)

# %%
dados['tempo'].hist(bins = 5)

# %%
dados['g-19'].hist(bins = 100)

# %%
dados.describe()
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
ges = dados.loc[:, 'g-0':'g-771']

# %%
ges.describe().T['mean'].hist(bins = 50)

# %%
ges.describe().T['min'].hist(bins = 50)

# %%
ges.describe().T['max'].hist(bins = 50)

# %%
ces = dados.loc[:, 'c-0':'c-99']

# %%
ces.describe().T['mean'].hist(bins = 50)

# %%
ces.describe().T['min'].hist(bins = 50)

# %%
ces.describe().T['max'].hist(bins = 50)

# %%
plt.figure(figsize= (10, 8))
sns.boxplot(y = 'g-0', x='tratamento', data=dados)

# %%
#testando o .boxplot()

plt.figure(figsize= (10, 8))
sns.boxplot(x = 'tratamento', y='g-1', data=dados)

# %% [markdown]
# ***Anotações importantes***
#
# - clue.io - verificar o site
#
# - o Seaborn se mostrou muito útil para melhorar a visualização de dados, aprender mais
#
# - verificar outras formas de visualização
#
# - os gráficos destorcidos pode ocorrer por alguns motivos: a) pode ser pela grande frequência em diferentes entradas; b) pela pouca quantidade de dados disponíveis, tornando a análise confusa.
#
# _____________________________________

# %% [markdown]
# ###AULA 03

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
pd.crosstab(dados['dose'], dados['tempo'])
# Out:
# dose         D1        D2
# tempo
# 24     0.163181  0.163181
# 48     0.182834  0.163601
# 72     0.164063  0.163139

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'])
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24              301       3585
#      48              343       4011
#      72              307       3600
# D2   24              305       3581
#      48              305       3591
#      72              305       3580

# %%
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], normalize='index')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.077458   0.922542
#      48         0.078778   0.921222
#      72         0.078577   0.921423
# D2   24         0.078487   0.921513
#      48         0.078285   0.921715
#      72         0.078507   0.921493

# %%
# Desafio 02
pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc='mean')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24        -0.251760   0.367996
#      48        -0.122773   0.412469
#      72        -0.295271   0.286250
# D2   24         0.010754   0.115253
#      48         0.013174   0.214480
#      72         0.070250   0.253439

# %%
sns.scatterplot(x= dados['g-0'], y= 'g-8', data = dados)

# %%
sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'yellow'})

# %%
  sns.lmplot(data=dados, x='g-0', y='g-8', line_kws={'color':'yellow'}, col='tratamento', row='tempo')

# %%
dados.loc[:,'g-0':'g-771'].corr()
# Out:
#             g-0       g-1       g-2  ...     g-769     g-770     g-771
# g-0    1.000000  0.086032  0.176188  ... -0.127375 -0.514201  0.405908
# g-1    0.086032  1.000000 -0.054518  ... -0.006866 -0.095108 -0.032233
# g-2    0.176188 -0.054518  1.000000  ...  0.014489 -0.078661  0.103985
# g-3    0.011266 -0.027855  0.042633  ... -0.206077 -0.002142  0.058219
# g-4    0.403153  0.193647  0.013968  ... -0.172727 -0.363673  0.250713
# ...         ...       ...       ...  ...       ...       ...       ...
# g-767 -0.052622 -0.003378 -0.053149  ...  0.065450  0.008603 -0.001136
# g-768  0.300241 -0.030756  0.115415  ...  0.079364 -0.382607  0.351651
# g-769 -0.127375 -0.006866  0.014489  ...  1.000000  0.135853 -0.083713
# g-770 -0.514201 -0.095108 -0.078661  ...  0.135853  1.000000 -0.425063
# g-771  0.405908 -0.032233  0.103985  ... -0.083713 -0.425063  1.000000
#
# [772 rows x 772 columns]

# %%
import numpy as np

corr = dados.loc[:,'g-0':'g-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
corr_celular = dados.loc[:,'c-0':'c-50'].corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_celular, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_celular, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Desafio 01: Tentar fazer a tabela de frequências com .groupby()
#
# Desafio 02: Normalizar pela coluna.
#
# Desafio 03: Explorar outros agregadores.
#
# Desafio 04: Explorar o melt.
#
# Desafio 05: Calcular e analisar a correlação entre Gs e Cs. Refletir sobre os efeitos biológicos.
#
# Desafio 06: explorar o código que gera a diagonal de correlação.
#
# Desafio 07: Resumo da aula de hoje.

# %%
#Desafio 01

dados.groupby(by=['dose', 'tratamento', 'tempo'])['dose'].count().unstack()
# Out:
# tempo                24    48    72
# dose tratamento
# D1   com_controle   301   343   307
#      com_droga     3585  4011  3600
# D2   com_controle   305   305   305
#      com_droga     3581  3591  3580

# %%
#Desafio 02
pd.crosstab([dados['dose'], dados['tempo']],  dados['tratamento'], normalize='columns')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24         0.161308   0.163341
#      48         0.183816   0.182750
#      72         0.164523   0.164024
# D2   24         0.163451   0.163158
#      48         0.163451   0.163614
#      72         0.163451   0.163113

# %%
#Desafio 03

pd.crosstab([dados['dose'], dados['tempo']], dados['tratamento'], values = dados['g-0'], aggfunc='max')
# Out:
# tratamento  com_controle  com_droga
# dose tempo
# D1   24            3.226      9.908
#      48            3.423     10.000
#      72            2.584      9.355
# D2   24            2.601      7.167
#      48            4.335     10.000
#      72            4.670     10.000

# %%
#Desafio 04

dados.groupby(by=['dose', 'tratamento', 'tempo'])['dose'].count().unstack().melt()
# Out:
#     tempo  value
# 0      24    301
# 1      24   3585
# 2      24    305
# 3      24   3581
# 4      48    343
# 5      48   4011
# 6      48    305
# 7      48   3591
# 8      72    307
# 9      72   3600
# 10     72    305
# 11     72   3580

# %%
#Desafio 05

corr_gc = dados.corr().loc['c-0':'c-50','g-0':'g-50']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_gc, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr_gc, mask=mask, cmap=cmap, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ***Resumo da aula de hoje***
#
# Já tinha me deparado com várias da análises comentadas na aula de hoje, na disciplina de estatística da faculdade, entretanto não sabia como fazer em python. Esse conteúdo está sendo muito proveitoso para mim. O método crosstab e o groupby tb se mostraram ótimas ferramentas.

# %% [markdown]
# ###AULA 04

# %%
url_exper = "https://raw.githubusercontent.com/alura-cursos/imersaodados3/main/dados/dados_resultados.csv"
 
dados_resultados = pd.read_csv(url_exper)
 
dados_resultados
# Out:
#                  id  ...  wnt_inhibitor
# 0      id_000644bb2  ...              0
# 1      id_000779bfc  ...              0
# 2      id_000a6266a  ...              0
# 3      id_0015fd391  ...              0
# 4      id_001626bd3  ...              0
# ...             ...  ...            ...
# 23809  id_fffb1ceed  ...              0
# 23810  id_fffb70c0c  ...              0
# 23811  id_fffc1c3f4  ...              0
# 23812  id_fffcb9e7c  ...              0
# 23813  id_ffffdd77b  ...              0
#
# [23814 rows x 207 columns]

# %%
dados_resultados['acat_inhibitor'].unique()
# Out:
# array([0, 1])

# %%
dados_resultados['acetylcholine_receptor_agonist'].unique()
# Out:
# array([0, 1])

# %%
contagem_moa = dados_resultados.drop('id', axis=1).sum().sort_values(ascending=False)
contagem_moa
# Out:
# nfkb_inhibitor                                832
# proteasome_inhibitor                          726
# cyclooxygenase_inhibitor                      435
# dopamine_receptor_antagonist                  424
# serotonin_receptor_antagonist                 404
#                                              ...
# protein_phosphatase_inhibitor                   6
# autotaxin_inhibitor                             6
# diuretic                                        6
# erbb2_inhibitor                                 1
# atp-sensitive_potassium_channel_antagonist      1
# Length: 206, dtype: int64

# %%
dados_resultados.drop('id', axis=1).sum(axis=1)
# Out:
# 0        1
# 1        0
# 2        3
# 3        0
# 4        1
#         ..
# 23809    1
# 23810    1
# 23811    0
# 23812    1
# 23813    0
# Length: 23814, dtype: int64

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados.head()
# Out:
#              id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0  id_000644bb2                            0  ...              0      1
# 1  id_000779bfc                            0  ...              0      0
# 2  id_000a6266a                            0  ...              0      3
# 3  id_0015fd391                            0  ...              0      0
# 4  id_001626bd3                            0  ...              0      1
#
# [5 rows x 208 columns]

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] !=0)
dados_resultados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0      id_000644bb2                            0  ...      1       True
# 1      id_000779bfc                            0  ...      0      False
# 2      id_000a6266a                            0  ...      3       True
# 3      id_0015fd391                            0  ...      0      False
# 4      id_001626bd3                            0  ...      1       True
# ...             ...                          ...  ...    ...        ...
# 23809  id_fffb1ceed                            0  ...      1       True
# 23810  id_fffb70c0c                            0  ...      1       True
# 23811  id_fffc1c3f4                            0  ...      0      False
# 23812  id_fffcb9e7c                            0  ...      1       True
# 23813  id_ffffdd77b                            0  ...      0      False
#
# [23814 rows x 209 columns]

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

composto_principal = dados_combinados['droga'].value_counts().index[:11]

plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('droga in @composto_principal'), y='g-0', x='droga')

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data = dados_combinados.query('droga in @composto_principal'), y='g-0', x='droga', hue='ativo_moa')

# %%
#Desafio 01

indices = [i.split('_')[-1] for i in contagem_moa.index]
indices[:20]
# Out:
# ['inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'antagonist',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'inhibitor',
#  'antagonist',
#  'inhibitor',
#  'inhibitor',
#  'blocker',
#  'inhibitor',
#  'inhibitor',
#  'agonist',
#  'inhibitor',
#  'agonist']

# %%
n_contagem = pd.DataFrame(data={'acao':indices, 'ocorrencia':contagem_moa.values})
n_contagem
# Out:
#            acao  ocorrencia
# 0     inhibitor         832
# 1     inhibitor         726
# 2     inhibitor         435
# 3    antagonist         424
# 4    antagonist         404
# ..          ...         ...
# 201   inhibitor           6
# 202   inhibitor           6
# 203    diuretic           6
# 204   inhibitor           1
# 205  antagonist           1
#
# [206 rows x 2 columns]

# %%
top_10 = n_contagem.groupby(by=['acao']).sum()['ocorrencia'].sort_values(ascending=False)[:10]
top_10 = top_10.reset_index()

plt.figure(figsize=(15,9))
ax = sns.barplot(data = top_10, x ='acao', y='ocorrencia')
for i, r in top_10.iterrows():
    ax.text(i, r['ocorrencia'], r['ocorrencia'], color='blue', ha="center", fontsize=10)

plt.show()

# %%
#Desafio 02

eh_controle = dados_combinados['tratamento'] == 'com_controle'
dados_combinados['eh_controle'] = eh_controle.astype('int')
dados_combinados
# Out:
#                  id    tratamento  tempo  ... n_moa ativo_moa  eh_controle
# 0      id_000644bb2     com_droga     24  ...     1      True            0
# 1      id_000779bfc     com_droga     72  ...     0     False            0
# 2      id_000a6266a     com_droga     48  ...     3      True            0
# 3      id_0015fd391     com_droga     48  ...     0     False            0
# 4      id_001626bd3     com_droga     72  ...     1      True            0
# ...             ...           ...    ...  ...   ...       ...          ...
# 23809  id_fffb1ceed     com_droga     24  ...     1      True            0
# 23810  id_fffb70c0c     com_droga     24  ...     1      True            0
# 23811  id_fffc1c3f4  com_controle     48  ...     0     False            1
# 23812  id_fffcb9e7c     com_droga     24  ...     1      True            0
# 23813  id_ffffdd77b     com_droga     72  ...     0     False            0
#
# [23814 rows x 880 columns]

# %%
#Desafio 03

tempo24 = dados_combinados['tempo'] == 24
tempo48 = dados_combinados['tempo'] == 48
tempo72 = dados_combinados['tempo'] == 72

dados_combinados['tempo24'],dados_combinados['tempo48'],dados_combinados['tempo72'] = [tempo24.astype('int'),tempo48.astype('int'),tempo72.astype('int')]
dados_combinados
# Out:
#                  id    tratamento  tempo  ... tempo24 tempo48  tempo72
# 0      id_000644bb2     com_droga     24  ...       1       0        0
# 1      id_000779bfc     com_droga     72  ...       0       0        1
# 2      id_000a6266a     com_droga     48  ...       0       1        0
# 3      id_0015fd391     com_droga     48  ...       0       1        0
# 4      id_001626bd3     com_droga     72  ...       0       0        1
# ...             ...           ...    ...  ...     ...     ...      ...
# 23809  id_fffb1ceed     com_droga     24  ...       1       0        0
# 23810  id_fffb70c0c     com_droga     24  ...       1       0        0
# 23811  id_fffc1c3f4  com_controle     48  ...       0       1        0
# 23812  id_fffcb9e7c     com_droga     24  ...       1       0        0
# 23813  id_ffffdd77b     com_droga     72  ...       0       0        1
#
# [23814 rows x 883 columns]

# %%
#Desafio 05

ch_composto = dados_combinados[dados_combinados['droga'] == '9f80f3f77']
controle = dados_combinados[dados_combinados['tratamento'] == 'com_controle']

# %%
sns.set()

fig, axs = plt.subplots(1, 2, figsize=(16, 8))
sns.boxplot(data=ch_composto, y='g-0', x='tempo', hue='dose', ax=axs[0])
sns.boxplot(data=controle, y='g-0', x='tempo', hue='dose', ax= axs[1])
axs[0].set_title('Droga 9f80f3f77')
axs[1].set_title('Controle')
# Out:
# Text(0.5, 1.0, 'Controle')

# %%
#Desafio 06
